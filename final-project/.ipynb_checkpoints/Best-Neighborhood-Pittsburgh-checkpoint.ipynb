# %% [markdown]
# # Best Neighborhood in Pittsburgh...?

# %% [markdown]
# ## Introduction:
#
# This small project aims to use a simple metric to make an informed and comprehensive analysis of the various neighborhoods in Pittsburgh to ultimately determine which neighborhood is the best, utilizing Python *pandas dataframes* and geopandas as the primary tools for data analysis.
#
# ## Metric:
#
# My metric to determine which neighborhood is the best in Pittsburgh is **Bus Stops**. In order to comprehensively evaluate this and analyze this, I will be comparing both Bus Stop *Density* and Bus Stop *Usage* for each neighborhood. For the former I will pull data from the Port Authority Transit Stops dataset. For the latter I will analyze data from the Bus Stop Usage dataset and Port Authority Monthly Average Ridership dataset. The scoring table will be similar to the following:
#
# | Neighborhood      | Bus Stop Density  | Bus Stop Usage |              |
# | ----------------- | ----------------- | -------------- | ------------ |
# | Westwood          |                   |                |              |
# | 31st ward         |                   |                |              |
# | Arlington         |                   |                |              |
# | Allegheny Center  |                   |                |              |
# | Allegheny West    |                   |                |              |
# | ...               |                   |                |              |
# | Woods Run- Halls Grove |              |                |              |
#
# As you can tell, there will be some difficulties in deciding which neighborhood really is the best neighborhood just from looking at this table alone! How are we going to decide *whether* and *when* Bus Stop Density should outweigh Bus Stop Usage, and vice versa? And **how** do we even calculate Bus Stop Density, if we are not immediately given the numbers? Let's dive into the data to find out!
#
# ## Best Neighborhood:
#
# Section in progress!
#
# ## Conclusion:
#
# Section in progress!

# %% [markdown]
# # Data Analysis
#
# Let's dive into the data analysis! First, we need to load the data, and we will do so by first **streaming** the relevant data from the WPRDC website. Let's take a look at both the data *dictionary* (which gives us useful information about the dataset fields) and the dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# dictionary
dictTS  = pd.read_csv("https://data.wprdc.org/datastore/dump/0a26e18e-f78b-43d2-8c75-2498ae255ecf")

# display first 5 results of salary2016 df
dictTS
# Out:
#          Field                 Description
# 0   InternalID                          ID
# 1         Name                   Stop Name
# 2   ExternalID                 External ID
# 3    Direction                   Direction
# 4          Lat     Latitude (y Coordinate)
# 5         Long    Longitude (x coordinate)
# 6   Time_Point  Is this stop a time point?
# 7      NewZone               New Fare Zone
# 8   No_Rts_Ser  Routes served by this stop
# 9   Routes_161                      Routes
# 10        Mode                        Mode
# 11  Public_She                     Shelter
# 12  Public_Sto            Stop description

# %%
import geopandas as gpd

# load transit stop data
dbf = r'PAAC_Stops_1611.dbf'
table = gpd.read_file(dbf)
tableTS = pd.DataFrame(table)

tableTS.head()
# Out:
#   InternalID                     Name  ExternalID Direction        Lat  \
# 0     S00010       10TH AVE AT ANN ST     11652.0   Inbound  40.406334
# 1     N71237  10TH AVE AT GARFIELD ST     20654.0  Outbound  40.606766
# 2     N71239    10TH AVE AT ORMOND ST     20656.0  Outbound  40.608314
# 3     N71238    10TH AVE AT SUMMIT ST     20655.0  Outbound  40.607561
# 4     S00080     12TH AVE AT AMITY ST     11650.0   Inbound  40.404325
#
#         Long Time_Point NewZone  No_Rts_Ser Routes_161 Mode  Public_She  \
# 0 -79.908116         No      1A         1.0        53L  Bus  No Shelter
# 1 -79.753111         No       2         1.0        P10  Bus  No Shelter
# 2 -79.750500         No       2         1.0        P10  Bus  No Shelter
# 3 -79.751760         No       2         1.0        P10  Bus  No Shelter
# 4 -79.908139         No      1A         2.0    53, 53L  Bus  No Shelter
#
#   Public_Sto geometry
# 0   Bus Stop     None
# 1   Bus Stop     None
# 2   Bus Stop     None
# 3   Bus Stop     None
# 4   Bus Stop     None

# %% [markdown]
# Sweet, we have our Port Authority Transit Stops data. Notice how many different columns it has! Pay special attention to the 6th and 7th columns, **'Lat'**(Latitude) and **'Long'**(Longitude). Let's display them more clearly:

# %%
tableTS[['Name','Lat','Long']].head(10)
# Out:
#                       Name        Lat       Long
# 0       10TH AVE AT ANN ST  40.406334 -79.908116
# 1  10TH AVE AT GARFIELD ST  40.606766 -79.753111
# 2    10TH AVE AT ORMOND ST  40.608314 -79.750500
# 3    10TH AVE AT SUMMIT ST  40.607561 -79.751760
# 4     12TH AVE AT AMITY ST  40.404325 -79.908139
# 5  12TH AVE AT AMITY ST FS  40.404339 -79.908339
# 6      16TH ST AT PENN AVE  40.448759 -79.987314
# 7       1ST AVE AT BOYD ST  40.599348 -79.755460
# 8       1ST AVE AT LOCK ST  40.600002 -79.752677
# 9      22ND AVE AT MAIN ST  40.397642 -79.901809

# %%
mapTS = gpd.read_file("transit_stops/PAAC_Stops_1909.shp") # read in the shapefile

mapTS.head()
# Out:
#    StopID                            Stop_name  CleverID Direction Timepoint  \
# 0  E00175  26TH ST AT PENN AVE FS (SPRING WAY)    2593.0   Inbound         N
# 1  E00180               28TH ST AT LIBERTY AVE    2161.0   Inbound         N
# 2  E00270                32ND ST AT SPRING WAY    2410.0  Outbound         N
# 3  E00420                 40TH ST AT BUTLER ST    1199.0  Outbound         N
# 4  E00430            40TH ST AT DAVIDSON ST FS   20106.0  Outbound         N
#
#    Routes_ser  Routes_cou   Latitude  Longitude Mode     Shelter Stop_type  \
# 0  54, 88, 91         3.0  40.454635 -79.978170  Bus  No Shelter  Bus Stop
# 1          54         1.0  40.456288 -79.974651  Bus  No Shelter  Bus Stop
# 2  54, 88, 91         3.0  40.460347 -79.969436  Bus  No Shelter  Bus Stop
# 3          93         1.0  40.468655 -79.962115  Bus  No Shelter  Bus Stop
# 4          93         1.0  40.467676 -79.960929  Bus  No Shelter  Bus Stop
#
#    On_avwk_FY  Off_avwk_F On_avwk__1 Off_avwk_1  AvgWkdy_De  \
# 0   34.531580   43.900523         35         44        0.03
# 1    1.304759   10.216890          1         10        0.03
# 2   13.184478   33.410865         13         33        0.04
# 3    1.038249   28.682688          1         29        0.05
# 4    0.163421   12.588603          0         13        0.00
#
#                          geometry
# 0  POINT (1348499.759 416298.200)
# 1  POINT (1349493.900 416875.511)
# 2  POINT (1350981.820 418317.228)
# 3  POINT (1353094.135 421291.781)
# 4  POINT (1353415.081 420926.980)

# %%
mapTS[['Stop_name', 'Latitude','Longitude','geometry']]
# Out:
#                                   Stop_name   Latitude  Longitude  \
# 0       26TH ST AT PENN AVE FS (SPRING WAY)  40.454635 -79.978170
# 1                    28TH ST AT LIBERTY AVE  40.456288 -79.974651
# 2                     32ND ST AT SPRING WAY  40.460347 -79.969436
# 3                      40TH ST AT BUTLER ST  40.468655 -79.962115
# 4                 40TH ST AT DAVIDSON ST FS  40.467676 -79.960929
# ...                                     ...        ...        ...
# 6940  BOWER HILL RD AT BEDNER'S FARM MARKET  40.361434 -80.089310
# 6941          WASHINGTON RD AT CONSOL DR FS  40.345641 -80.057725
# 6942         VILLAGE DR AT WASHINGTON RD FS  40.342759 -80.059715
# 6943                SHIRE PL AT BREINING ST  40.388372 -80.007092
# 6944             KANE BLVD AT BOWER HILL RD  40.371747 -80.082735
#
#                             geometry
# 0     POINT (1348499.759 416298.200)
# 1     POINT (1349493.900 416875.511)
# 2     POINT (1350981.820 418317.228)
# 3     POINT (1353094.135 421291.781)
# 4     POINT (1353415.081 420926.980)
# ...                              ...
# 6940  POINT (1316682.236 383156.969)
# 6941  POINT (1325330.634 377174.082)
# 6942  POINT (1324748.686 376139.046)
# 6943  POINT (1339836.900 392370.971)
# 6944  POINT (1318613.074 386864.171)
#
# [6336 rows x 4 columns]

# %%
# filter out non-"Bus Stops"
mapTS = mapTS[mapTS["Stop_type"] == "Bus Stop"]

plt.style.use('dark_background')
mapTS.plot(figsize=(12,8)) # plot the geopandas dataframe

# %% [markdown]
# **GEOPANDAS HERE** to show shapefile, map, and then using Pittsburgh neighborhoods shapefile to analyze the cutoffs and categorize, then count and divide by area to get density.

# %%
# load neighborhoods location data
neighborhoods = gpd.read_file("neighborhoods/Neighborhoods_.shp") # read in the shapefile

neighborhoods.plot(column='area', 
                   cmap='OrRd', 
                   edgecolor='orange', 
                   legend=True,
                   legend_kwds={'label':'Neighborhood Size'},
                   figsize=(12,8)) # plot the geopandas dataframe

# %%
neighborhoods[['hood', 'area', 'perimeter', 'geometry']]
# Out:
#                     hood        area  perimeter  \
# 0        Central Oakland   7843108.0  11526.863
# 1          North Oakland  13904629.0  20941.387
# 2           West Oakland   5999801.5  18271.426
# 3       Crawford-Roberts   7202139.0  15696.759
# 4         Strip District  16947852.0  23903.078
# ..                   ...         ...        ...
# 85             Ridgemont  10278895.0  16268.131
# 86              West End   5579501.0  18776.656
# 87  California-Kirkbride   6050988.0  11711.301
# 88            Glen Hazel  12713036.0  18931.703
# 89           Perry North         NaN        NaN
#
#                                              geometry
# 0   POLYGON ((-79.95304 40.44203, -79.95302 40.442...
# 1   POLYGON ((-79.95455 40.45882, -79.95427 40.458...
# 2   POLYGON ((-79.96230 40.44294, -79.96220 40.442...
# 3   POLYGON ((-79.98275 40.44641, -79.98273 40.446...
# 4   POLYGON ((-79.97494 40.45629, -79.97484 40.456...
# ..                                                ...
# 85  POLYGON ((-80.03431 40.43366, -80.03424 40.433...
# 86  POLYGON ((-80.02869 40.44454, -80.02845 40.444...
# 87  POLYGON ((-80.02039 40.46285, -80.02022 40.462...
# 88  POLYGON ((-79.92030 40.41205, -79.92027 40.412...
# 89  POLYGON ((-80.01783 40.49736, -80.01787 40.497...
#
# [90 rows x 4 columns]

# %% [markdown]
# We want to classify the bus stops into their respective neighborhoods. Let's use the **shapely** library's *Point* and *Polygon* classes.

# %%
from shapely.geometry import Point, Polygon
import geopandas.tools

# for each bus stop
    # for each neighborhood

# mapTS.loc[0,'geometry'].intersects(neighborhoods.loc[0, 'geometry'])
# Out:
# /opt/tljh/user/lib/python3.6/site-packages/pyproj/crs.py:77: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method.
#   return _prepare_from_string(" ".join(pjargs))
# /opt/tljh/user/lib/python3.6/site-packages/geopandas/tools/sjoin.py:61: UserWarning: CRS of frames being joined does not match!(+init=epsg:4326 +type=crs != epsg:4326)
#   "(%s != %s)" % (left_df.crs, right_df.crs)
# /opt/tljh/user/lib/python3.6/site-packages/geopandas/base.py:104: UserWarning: Cannot generate spatial index: Missing package `rtree`.
#   warn("Cannot generate spatial index: Missing package `rtree`.")
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-71-418cc4b34354> in <module>
#       7 TSgeodf.crs = {'init':'epsg:4326'}
#       8
# ----> 9 TSwithHoods = gpd.sjoin(TSgeodf, neighborhoods, op='within')
#      10 TSwithHoods.head()
#      11 # mapTS.loc[0,'geometry'].intersects(neighborhoods.loc[0, 'geometry'])
#
# /opt/tljh/user/lib/python3.6/site-packages/geopandas/tools/sjoin.py in sjoin(left_df, right_df, how, op, lsuffix, rsuffix)
#     124     if tree_idx_right:
#     125         idxmatch = left_df.geometry.apply(lambda x: x.bounds).apply(
# --> 126             lambda x: list(tree_idx.intersection(x)) if not x == () else []
#     127         )
#     128         idxmatch = idxmatch[idxmatch.apply(len) > 0]
#
# /opt/tljh/user/lib/python3.6/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4043             else:
#    4044                 values = self.astype(object).values
# -> 4045                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4046
#    4047         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# /opt/tljh/user/lib/python3.6/site-packages/geopandas/tools/sjoin.py in <lambda>(x)
#     124     if tree_idx_right:
#     125         idxmatch = left_df.geometry.apply(lambda x: x.bounds).apply(
# --> 126             lambda x: list(tree_idx.intersection(x)) if not x == () else []
#     127         )
#     128         idxmatch = idxmatch[idxmatch.apply(len) > 0]
#
# AttributeError: 'NoneType' object has no attribute 'intersection'

# %%
TShood = mapTS.merge(neighborhoods, how='left', 
                            left_on='geometry', 
                            right_on='geometry')

TShood[['hood','geometry']]
TSmap.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# *Now we load the remaining data we need.

# %%
# load 2017 salary data
salary2017 = pd.read_csv("https://data.wprdc.org/datastore/dump/4d09cd16-3e45-4d71-9607-40b545457cb7")

# load 2018 salary data
salary2018 = pd.read_csv("https://data.wprdc.org/datastore/dump/8f5d74ba-b011-4a34-91a9-24f9c7447491")

# %% [markdown]
# Let's do a preliminary analysis on the three yearly datasets looking only at annual salary. Since our main goal is to evaluate the metric for the different neighborhoods in Pittsburgh, let's separate our data based on neighborhood.
