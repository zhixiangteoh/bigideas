# %%
# test

# %%
name = input("Enter your name:")
# Out:
# Enter your name: Teoh

# %%
iterations = int(input("Enter your favorite number (what happens is a surprise):"))
# Out:
# Enter your favorite number (what happens is a surprise): 20

# %%
for i in range(iterations):
    print(name + " " +str(i+1))
# Out:
# Teoh 1
# Teoh 2
# Teoh 3
# Teoh 4
# Teoh 5
# Teoh 6
# Teoh 7
# Teoh 8
# Teoh 9
# Teoh 10
# Teoh 11
# Teoh 12
# Teoh 13
# Teoh 14
# Teoh 15
# Teoh 16
# Teoh 17
# Teoh 18
# Teoh 19
# Teoh 20

# %%
ahh = input("Enter a string: ")
print(ahh.upper())
# Out:
# Enter a string:  fd
# FD

# %%
age = input("Please enter your age:")

print("Congratulations, you are " + age + " years old!")
# Out:
# Please enter your age: 15
# Congratulations, you are 15 years old!
